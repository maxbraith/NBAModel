# %%
import tensorflow as tf
import os
import pandas as pd 
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense, InputLayer
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('nbaDatabase.csv')
df
# Out:
#                  date               homeTeam homeTeam_id  \
# 0       June 17, 2024         Boston Celtics         BOS
# 1       June 14, 2024       Dallas Mavericks         DAL
# 2       June 12, 2024       Dallas Mavericks         DAL
# 3       June 09, 2024         Boston Celtics         BOS
# 4       June 06, 2024         Boston Celtics         BOS
# ...               ...                    ...         ...
# 12879  April 30, 2014        Houston Rockets         HOU
# 12880  April 30, 2014      San Antonio Spurs         SAS
# 12881  April 29, 2014          Chicago Bulls         CHI
# 12882  April 29, 2014  Oklahoma City Thunder         OKC
# 12883  April 29, 2014   Los Angeles Clippers         LAC
#
#        homeTeam_points_total  homeTeam_points_q1  homeTeam_points_q2  \
# 0                        106                  28                  39
# 1                        122                  34                  27
# 2                         99                  31                  20
# 3                        105                  25                  29
# 4                        107                  37                  26
# ...                      ...                 ...                 ...
# 12879                    108                  30                  26
# 12880                    109                  27                  31
# 12881                     69                  15                  26
# 12882                     99                  25                  18
# 12883                    113                  31                  24
#
#        homeTeam_points_q3  homeTeam_points_q4  homeTeam_points_1OT  \
# 0                      19                  20                    0
# 1                      31                  30                    0
# 2                      19                  29                    0
# 3                      29                  22                    0
# 4                      23                  21                    0
# ...                   ...                 ...                  ...
# 12879                  26                  26                    0
# 12880                  21                  30                    0
# 12881                  11                  17                    0
# 12882                  27                  20                    9
# 12883                  22                  36                    0
#
#        homeTeam_points_2OT  ...  awayTeam_3P  awayTeam_O_Reb awayTeam_D_Reb  \
# 0                        0  ...        11-37               7             28
# 1                        0  ...        14-41               4             27
# 2                        0  ...        17-46               6             30
# 3                        0  ...         6-26               9             34
# 4                        0  ...         7-27              10             33
# ...                    ...  ...          ...             ...            ...
# 12879                    0  ...         9-25               9             25
# 12880                    0  ...        12-28               9             38
# 12881                    0  ...          2-9              13             36
# 12882                    0  ...         7-19              13             37
# 12883                    0  ...        10-26              13             29
#
#       awayTeam_Total_Reb  awayTeam_Ast  awayTeam_Stl  awayTeam_Blk  \
# 0                     35            18             4             4
# 1                     31            18             2             5
# 2                     36            26             4             6
# 3                     43            21             5             3
# 4                     43             9             8             1
# ...                  ...           ...           ...           ...
# 12879                 34            14             8            14
# 12880                 47            18             2             8
# 12881                 49            16             9            11
# 12882                 50            21            11             3
# 12883                 42            24             6             1
#
#        awayTeam_TO  awayTeam_PF                winner
# 0               13           20        Boston Celtics
# 1               13           19      Dallas Mavericks
# 2                9           19        Boston Celtics
# 3               15           17        Boston Celtics
# 4               11           16        Boston Celtics
# ...            ...          ...                   ...
# 12879           10           21       Houston Rockets
# 12880            8           21     San Antonio Spurs
# 12881           12           19    Washington Wizards
# 12882            9           21     Memphis Grizzlies
# 12883           13           28  Los Angeles Clippers
#
# [12884 rows x 44 columns]

# %%
subjectID_dict = {
    "ATL": 1,
    "BOS": 2,
    "BKN": 3,
    "CHA": 4,
    "CHI": 5,
    "CLE": 6,
    "DAL": 7,
    "DEN": 8,
    "DET": 9,
    "GSW": 10,
    "HOU": 11,
    "IND": 12,
    "LAC": 13,
    "LAL": 14,
    "MEM": 15,
    "MIA": 16,
    "MIL": 17,
    "MIN": 18,
    "NOP": 19,
    "NYK": 20,
    "OKC": 21,
    "ORL": 22,
    "PHI": 23,
    "PHX": 24,
    "POR": 25,
    "SAC": 26,
    "SAS": 27,
    "TOR": 28,
    "UTA": 29,
    "WAS": 30
}

# %%
df["homeTeamSubject_id"] = df["homeTeam_id"].map(subjectID_dict)
df["awayTeamSubject_id"] = df["awayTeam_id"].map(subjectID_dict)

cols = df.columns.tolist()
cols.insert(cols.index("homeTeam_id") + 1, cols.pop(cols.index("homeTeamSubject_id")))
cols.insert(cols.index("awayTeam_id") + 1, cols.pop(cols.index("awayTeamSubject_id")))
df = df[cols]

df
# Out:
#                  date               homeTeam homeTeam_id  homeTeamSubject_id  \
# 0       June 17, 2024         Boston Celtics         BOS                   2
# 1       June 14, 2024       Dallas Mavericks         DAL                   7
# 2       June 12, 2024       Dallas Mavericks         DAL                   7
# 3       June 09, 2024         Boston Celtics         BOS                   2
# 4       June 06, 2024         Boston Celtics         BOS                   2
# ...               ...                    ...         ...                 ...
# 12879  April 30, 2014        Houston Rockets         HOU                  11
# 12880  April 30, 2014      San Antonio Spurs         SAS                  27
# 12881  April 29, 2014          Chicago Bulls         CHI                   5
# 12882  April 29, 2014  Oklahoma City Thunder         OKC                  21
# 12883  April 29, 2014   Los Angeles Clippers         LAC                  13
#
#        homeTeam_points_total  homeTeam_points_q1  homeTeam_points_q2  \
# 0                        106                  28                  39
# 1                        122                  34                  27
# 2                         99                  31                  20
# 3                        105                  25                  29
# 4                        107                  37                  26
# ...                      ...                 ...                 ...
# 12879                    108                  30                  26
# 12880                    109                  27                  31
# 12881                     69                  15                  26
# 12882                     99                  25                  18
# 12883                    113                  31                  24
#
#        homeTeam_points_q3  homeTeam_points_q4  homeTeam_points_1OT  ...  \
# 0                      19                  20                    0  ...
# 1                      31                  30                    0  ...
# 2                      19                  29                    0  ...
# 3                      29                  22                    0  ...
# 4                      23                  21                    0  ...
# ...                   ...                 ...                  ...  ...
# 12879                  26                  26                    0  ...
# 12880                  21                  30                    0  ...
# 12881                  11                  17                    0  ...
# 12882                  27                  20                    9  ...
# 12883                  22                  36                    0  ...
#
#        awayTeam_3P  awayTeam_O_Reb  awayTeam_D_Reb awayTeam_Total_Reb  \
# 0            11-37               7              28                 35
# 1            14-41               4              27                 31
# 2            17-46               6              30                 36
# 3             6-26               9              34                 43
# 4             7-27              10              33                 43
# ...            ...             ...             ...                ...
# 12879         9-25               9              25                 34
# 12880        12-28               9              38                 47
# 12881          2-9              13              36                 49
# 12882         7-19              13              37                 50
# 12883        10-26              13              29                 42
#
#       awayTeam_Ast  awayTeam_Stl  awayTeam_Blk  awayTeam_TO  awayTeam_PF  \
# 0               18             4             4           13           20
# 1               18             2             5           13           19
# 2               26             4             6            9           19
# 3               21             5             3           15           17
# 4                9             8             1           11           16
# ...            ...           ...           ...          ...          ...
# 12879           14             8            14           10           21
# 12880           18             2             8            8           21
# 12881           16             9            11           12           19
# 12882           21            11             3            9           21
# 12883           24             6             1           13           28
#
#                      winner
# 0            Boston Celtics
# 1          Dallas Mavericks
# 2            Boston Celtics
# 3            Boston Celtics
# 4            Boston Celtics
# ...                     ...
# 12879       Houston Rockets
# 12880     San Antonio Spurs
# 12881    Washington Wizards
# 12882     Memphis Grizzlies
# 12883  Los Angeles Clippers
#
# [12884 rows x 46 columns]

# %%
#limit df to few variables
dfLim = df[[
    "date",
    "homeTeam",
    "homeTeamSubject_id", 
    "homeTeam_points_total", 
    "awayTeam",
    "awayTeamSubject_id", 
    "awayTeam_points_total",
    "winner"
]]
dfLim
# Out:
#                  date               homeTeam  homeTeamSubject_id  \
# 0       June 17, 2024         Boston Celtics                   2
# 1       June 14, 2024       Dallas Mavericks                   7
# 2       June 12, 2024       Dallas Mavericks                   7
# 3       June 09, 2024         Boston Celtics                   2
# 4       June 06, 2024         Boston Celtics                   2
# ...               ...                    ...                 ...
# 12879  April 30, 2014        Houston Rockets                  11
# 12880  April 30, 2014      San Antonio Spurs                  27
# 12881  April 29, 2014          Chicago Bulls                   5
# 12882  April 29, 2014  Oklahoma City Thunder                  21
# 12883  April 29, 2014   Los Angeles Clippers                  13
#
#        homeTeam_points_total                awayTeam  awayTeamSubject_id  \
# 0                        106        Dallas Mavericks                   7
# 1                        122          Boston Celtics                   2
# 2                         99          Boston Celtics                   2
# 3                        105        Dallas Mavericks                   7
# 4                        107        Dallas Mavericks                   7
# ...                      ...                     ...                 ...
# 12879                    108  Portland Trail Blazers                  25
# 12880                    109        Dallas Mavericks                   7
# 12881                     69      Washington Wizards                  30
# 12882                     99       Memphis Grizzlies                  15
# 12883                    113   Golden State Warriors                  10
#
#        awayTeam_points_total                winner
# 0                         88        Boston Celtics
# 1                         84      Dallas Mavericks
# 2                        106        Boston Celtics
# 3                         98        Boston Celtics
# 4                         89        Boston Celtics
# ...                      ...                   ...
# 12879                     98       Houston Rockets
# 12880                    103     San Antonio Spurs
# 12881                     75    Washington Wizards
# 12882                    100     Memphis Grizzlies
# 12883                    103  Los Angeles Clippers
#
# [12884 rows x 8 columns]

# %%
#reformat the dates so they can be compared
dfLim['date'] = dfLim['date'].apply(lambda x: datetime.strptime(x, "%B %d, %Y"))
dfLim
# Out:
# C:\Users\Max Braithwaite\AppData\Local\Temp\ipykernel_25820\4095227244.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfLim['date'] = dfLim['date'].apply(lambda x: datetime.strptime(x, "%B %d, %Y"))
#             date               homeTeam  homeTeamSubject_id  \
# 0     2024-06-17         Boston Celtics                   2
# 1     2024-06-14       Dallas Mavericks                   7
# 2     2024-06-12       Dallas Mavericks                   7
# 3     2024-06-09         Boston Celtics                   2
# 4     2024-06-06         Boston Celtics                   2
# ...          ...                    ...                 ...
# 12879 2014-04-30        Houston Rockets                  11
# 12880 2014-04-30      San Antonio Spurs                  27
# 12881 2014-04-29          Chicago Bulls                   5
# 12882 2014-04-29  Oklahoma City Thunder                  21
# 12883 2014-04-29   Los Angeles Clippers                  13
#
#        homeTeam_points_total                awayTeam  awayTeamSubject_id  \
# 0                        106        Dallas Mavericks                   7
# 1                        122          Boston Celtics                   2
# 2                         99          Boston Celtics                   2
# 3                        105        Dallas Mavericks                   7
# 4                        107        Dallas Mavericks                   7
# ...                      ...                     ...                 ...
# 12879                    108  Portland Trail Blazers                  25
# 12880                    109        Dallas Mavericks                   7
# 12881                     69      Washington Wizards                  30
# 12882                     99       Memphis Grizzlies                  15
# 12883                    113   Golden State Warriors                  10
#
#        awayTeam_points_total                winner
# 0                         88        Boston Celtics
# 1                         84      Dallas Mavericks
# 2                        106        Boston Celtics
# 3                         98        Boston Celtics
# 4                         89        Boston Celtics
# ...                      ...                   ...
# 12879                     98       Houston Rockets
# 12880                    103     San Antonio Spurs
# 12881                     75    Washington Wizards
# 12882                    100     Memphis Grizzlies
# 12883                    103  Los Angeles Clippers
#
# [12884 rows x 8 columns]

# %%
dfLim['winner_binary'] = (dfLim['winner'] == df['awayTeam']).astype(int)
dfLim
# Out:
# C:\Users\Max Braithwaite\AppData\Local\Temp\ipykernel_25820\472979383.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfLim['winner_binary'] = (dfLim['winner'] == df['awayTeam']).astype(int)
#             date               homeTeam  homeTeamSubject_id  \
# 0     2024-06-17         Boston Celtics                   2
# 1     2024-06-14       Dallas Mavericks                   7
# 2     2024-06-12       Dallas Mavericks                   7
# 3     2024-06-09         Boston Celtics                   2
# 4     2024-06-06         Boston Celtics                   2
# ...          ...                    ...                 ...
# 12879 2014-04-30        Houston Rockets                  11
# 12880 2014-04-30      San Antonio Spurs                  27
# 12881 2014-04-29          Chicago Bulls                   5
# 12882 2014-04-29  Oklahoma City Thunder                  21
# 12883 2014-04-29   Los Angeles Clippers                  13
#
#        homeTeam_points_total                awayTeam  awayTeamSubject_id  \
# 0                        106        Dallas Mavericks                   7
# 1                        122          Boston Celtics                   2
# 2                         99          Boston Celtics                   2
# 3                        105        Dallas Mavericks                   7
# 4                        107        Dallas Mavericks                   7
# ...                      ...                     ...                 ...
# 12879                    108  Portland Trail Blazers                  25
# 12880                    109        Dallas Mavericks                   7
# 12881                     69      Washington Wizards                  30
# 12882                     99       Memphis Grizzlies                  15
# 12883                    113   Golden State Warriors                  10
#
#        awayTeam_points_total                winner  winner_binary
# 0                         88        Boston Celtics              0
# 1                         84      Dallas Mavericks              0
# 2                        106        Boston Celtics              1
# 3                         98        Boston Celtics              0
# 4                         89        Boston Celtics              0
# ...                      ...                   ...            ...
# 12879                     98       Houston Rockets              0
# 12880                    103     San Antonio Spurs              0
# 12881                     75    Washington Wizards              1
# 12882                    100     Memphis Grizzlies              1
# 12883                    103  Los Angeles Clippers              0
#
# [12884 rows x 9 columns]

# %%
dfIDtoStat = pd.DataFrame(columns=['date', 'team_id', 'team_points_total'])
dfIDtoStat
# Out:
# Empty DataFrame
# Columns: [date, team_id, team_points_total]
# Index: []

# %%
for index, row in dfLim.iterrows():
    date = row['date']
    homeTeam_id = row['homeTeamSubject_id']
    homeTeam_points_total = row['homeTeam_points_total']
    awayTeam_id = row['awayTeamSubject_id']
    awayTeam_points_total = row['awayTeam_points_total']
    dfIDtoStat.loc[len(dfIDtoStat)] = {"date": date, 'team_id': homeTeam_id, 'team_points_total':homeTeam_points_total}
    dfIDtoStat.loc[len(dfIDtoStat)] = {"date": date, 'team_id': awayTeam_id, 'team_points_total':awayTeam_points_total}
dfIDtoStat
# Out:
#             date  team_id  team_points_total
# 0     2024-06-17        2                106
# 1     2024-06-17        7                 88
# 2     2024-06-14        7                122
# 3     2024-06-14        2                 84
# 4     2024-06-12        7                 99
# ...          ...      ...                ...
# 25763 2014-04-29       30                 75
# 25764 2014-04-29       21                 99
# 25765 2014-04-29       15                100
# 25766 2014-04-29       13                113
# 25767 2014-04-29       10                103
#
# [25768 rows x 3 columns]

# %%
dfIDtoStat.head()
# Out:
#         date  team_id  team_points_total
# 0 2024-06-17        2                106
# 1 2024-06-17        7                 88
# 2 2024-06-14        7                122
# 3 2024-06-14        2                 84
# 4 2024-06-12        7                 99

# %%
dfLim = dfLim.iloc[::-1].reset_index(drop=True)
dfLim
# Out:
#             date               homeTeam  homeTeamSubject_id  \
# 0     2014-04-29   Los Angeles Clippers                  13
# 1     2014-04-29  Oklahoma City Thunder                  21
# 2     2014-04-29          Chicago Bulls                   5
# 3     2014-04-30      San Antonio Spurs                  27
# 4     2014-04-30        Houston Rockets                  11
# ...          ...                    ...                 ...
# 12879 2024-06-06         Boston Celtics                   2
# 12880 2024-06-09         Boston Celtics                   2
# 12881 2024-06-12       Dallas Mavericks                   7
# 12882 2024-06-14       Dallas Mavericks                   7
# 12883 2024-06-17         Boston Celtics                   2
#
#        homeTeam_points_total                awayTeam  awayTeamSubject_id  \
# 0                        113   Golden State Warriors                  10
# 1                         99       Memphis Grizzlies                  15
# 2                         69      Washington Wizards                  30
# 3                        109        Dallas Mavericks                   7
# 4                        108  Portland Trail Blazers                  25
# ...                      ...                     ...                 ...
# 12879                    107        Dallas Mavericks                   7
# 12880                    105        Dallas Mavericks                   7
# 12881                     99          Boston Celtics                   2
# 12882                    122          Boston Celtics                   2
# 12883                    106        Dallas Mavericks                   7
#
#        awayTeam_points_total                winner  winner_binary
# 0                        103  Los Angeles Clippers              0
# 1                        100     Memphis Grizzlies              1
# 2                         75    Washington Wizards              1
# 3                        103     San Antonio Spurs              0
# 4                         98       Houston Rockets              0
# ...                      ...                   ...            ...
# 12879                     89        Boston Celtics              0
# 12880                     98        Boston Celtics              0
# 12881                    106        Boston Celtics              1
# 12882                     84      Dallas Mavericks              0
# 12883                     88        Boston Celtics              0
#
# [12884 rows x 9 columns]

# %%
dfIDtoStat = dfIDtoStat.iloc[::-1].reset_index(drop=True)
dfIDtoStat
# Out:
#             date  team_id  team_points_total
# 0     2014-04-29       10                103
# 1     2014-04-29       13                113
# 2     2014-04-29       15                100
# 3     2014-04-29       21                 99
# 4     2014-04-29       30                 75
# ...          ...      ...                ...
# 25763 2024-06-12        7                 99
# 25764 2024-06-14        2                 84
# 25765 2024-06-14        7                122
# 25766 2024-06-17        7                 88
# 25767 2024-06-17        2                106
#
# [25768 rows x 3 columns]

# %%
'''def df_to_X_y_Simple(df, window_size=5):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np)-window_size):
        row = [r for r in df_as_np[i:i+window_size]]
        X.append(row)
        label = df_as_np[i+window_size][0]
        y.append(label)
    return np.array(X), np.array(y)'''

def df_to_X_y(df, dfWindow, window_size):
    X = []
    y = []
    #each team must have played window_size games before data can be extracted
    for index, row in df.iterrows():
        homeTeam_id = row['homeTeamSubject_id']
        awayTeam_id = row['awayTeamSubject_id']
        date = row['date']
        #limit dfWindow to include rows that occured before date of row we are on
        dfWindow_before_date = dfWindow[dfWindow['date']< date]
        homeTeam_occurrences = dfWindow_before_date[dfWindow_before_date['team_id'] == homeTeam_id].shape[0]
        awayTeam_occurrences = dfWindow_before_date[dfWindow_before_date['team_id'] == awayTeam_id].shape[0]
        if homeTeam_occurrences > window_size and awayTeam_occurrences > window_size:
            homeTeam_window = (dfWindow_before_date[dfWindow_before_date['team_id'] == homeTeam_id].sort_values(by='date', ascending=False).head(window_size).drop(columns=['date', 'team_id']))
            awayTeam_window = (dfWindow_before_date[dfWindow_before_date['team_id'] == awayTeam_id].sort_values(by='date', ascending=False).head(window_size).drop(columns=['date', 'team_id']))
            homeTeam_window = homeTeam_window.to_numpy()
            awayTeam_window = awayTeam_window.to_numpy()
            combined_window = np.hstack((homeTeam_window, awayTeam_window))
            X.append(combined_window)
            y.append(row['winner_binary'])
    
    return np.array(X), np.array(y)

# %%
window_size =5 
exX =[]
exY = []
for index, row in dfLim.iterrows():
        homeTeam_id = row['homeTeamSubject_id']
        awayTeam_id = row['awayTeamSubject_id']
        date = row['date']
        #limit dfWindow to include rows that occured before date of row we are on
        dfWindow_before_date = dfIDtoStat[dfIDtoStat['date']< date]
        homeTeam_occurrences = dfWindow_before_date[dfWindow_before_date['team_id'] == homeTeam_id].shape[0]
        awayTeam_occurrences = dfWindow_before_date[dfWindow_before_date['team_id'] == awayTeam_id].shape[0]
        if homeTeam_occurrences > window_size and awayTeam_occurrences > window_size:
                homeTeam_window = (dfWindow_before_date[dfWindow_before_date['team_id'] == homeTeam_id].sort_values(by='date', ascending=False).head(window_size))
                awayTeam_window = (dfWindow_before_date[dfWindow_before_date['team_id'] == awayTeam_id].sort_values(by='date', ascending=False).head(window_size))
                print(date)
                print(homeTeam_window)
                print(awayTeam_window)
                print(type(homeTeam_window))
                homeTeam_window = homeTeam_window.drop(columns=['date', 'team_id'])
                awayTeam_window = awayTeam_window.drop(columns=['date', 'team_id'])
                homeTeam_window = homeTeam_window.to_numpy()
                awayTeam_window = awayTeam_window.to_numpy()
                combined_window = np.hstack((homeTeam_window, awayTeam_window))
                exX.append(combined_window)
                exY.append(row['winner_binary'])
                print(exX)
                print(exY)
                break
# Out:
# 2014-05-11 00:00:00
#          date  team_id  team_points_total
# 51 2014-05-09       13                112
# 42 2014-05-07       13                101
# 34 2014-05-05       13                122
# 25 2014-05-03       13                126
# 12 2014-05-01       13                 99
#          date  team_id  team_points_total
# 50 2014-05-09       21                118
# 43 2014-05-07       21                112
# 35 2014-05-05       21                105
# 27 2014-05-03       21                120
# 14 2014-05-01       21                104
# <class 'pandas.core.frame.DataFrame'>
# [array([[112, 118],
#        [101, 112],
#        [122, 105],
#        [126, 120],
#        [ 99, 104]], dtype=int64)]
# [0]

# %%
#X1.Shape is num data, window size, variables
X1, y1 = df_to_X_y(dfLim, dfIDtoStat, 5)
X1.shape, y1.shape
# Out:
# ((12773, 5, 2), (12773,))

# %%
#70-15-15 split
X1_train, X1_temp, y1_train, y1_temp = train_test_split(X1, y1, test_size=0.3, random_state=42)
X1_val, X1_test, y1_val, y1_test = train_test_split(X1_temp, y1_temp, test_size=0.5, random_state=42)
X1_train.shape, y1_train.shape, X1_val.shape, y1_val.shape, X1_test.shape, y1_test.shape
# Out:
# ((8941, 5, 2), (8941,), (1916, 5, 2), (1916,), (1916, 5, 2), (1916,))

# %%
model1 = Sequential()
model1.add(InputLayer((5, 2)))
model1.add(LSTM(64, activation='tanh', return_sequences=True))
model1.add(LSTM(32, activation='tanh'))
model1.add(Dense(16, activation='relu'))
model1.add(Dense(8, activation='relu'))
model1.add(Dense(1, activation='sigmoid'))

model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 5, 64)             17152
#
#  lstm_3 (LSTM)               (None, 32)                12416
#
#  dense (Dense)               (None, 16)                528
#
#  dense_1 (Dense)             (None, 8)                 136
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 30241 (118.13 KB)
# Trainable params: 30241 (118.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
earlystopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
model1.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model1.fit(X1_train, y1_train, validation_data=(X1_val, y1_val), epochs=100, callbacks=[earlystopping])
# Out:
# Epoch 1/100
# 280/280 [==============================] - 5s 6ms/step - loss: 0.6750 - accuracy: 0.5794 - val_loss: 0.6792 - val_accuracy: 0.5752
# Epoch 2/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6745 - accuracy: 0.5811 - val_loss: 0.6838 - val_accuracy: 0.5517
# Epoch 3/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6745 - accuracy: 0.5849 - val_loss: 0.6752 - val_accuracy: 0.5887
# Epoch 4/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6738 - accuracy: 0.5847 - val_loss: 0.6765 - val_accuracy: 0.5814
# Epoch 5/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6729 - accuracy: 0.5858 - val_loss: 0.6767 - val_accuracy: 0.5762
# Epoch 6/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6733 - accuracy: 0.5825 - val_loss: 0.6800 - val_accuracy: 0.5746
# Epoch 7/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6725 - accuracy: 0.5849 - val_loss: 0.6742 - val_accuracy: 0.5840
# Epoch 8/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6733 - accuracy: 0.5852 - val_loss: 0.6751 - val_accuracy: 0.5856
# Epoch 9/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6737 - accuracy: 0.5797 - val_loss: 0.6751 - val_accuracy: 0.5866
# Epoch 10/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6730 - accuracy: 0.5857 - val_loss: 0.6766 - val_accuracy: 0.5699
# Epoch 11/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6733 - accuracy: 0.5838 - val_loss: 0.6752 - val_accuracy: 0.5830
# Epoch 12/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6723 - accuracy: 0.5871 - val_loss: 0.6756 - val_accuracy: 0.5762
# Epoch 13/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6728 - accuracy: 0.5823 - val_loss: 0.6794 - val_accuracy: 0.5762
# Epoch 14/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6727 - accuracy: 0.5885 - val_loss: 0.6741 - val_accuracy: 0.5872
# Epoch 15/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6723 - accuracy: 0.5863 - val_loss: 0.6744 - val_accuracy: 0.5866
# Epoch 16/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6716 - accuracy: 0.5845 - val_loss: 0.6750 - val_accuracy: 0.5908
# Epoch 17/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6715 - accuracy: 0.5849 - val_loss: 0.6739 - val_accuracy: 0.5903
# Epoch 18/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6721 - accuracy: 0.5841 - val_loss: 0.6747 - val_accuracy: 0.5872
# Epoch 19/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6719 - accuracy: 0.5847 - val_loss: 0.6737 - val_accuracy: 0.5877
# Epoch 20/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6722 - accuracy: 0.5809 - val_loss: 0.6754 - val_accuracy: 0.5767
# Epoch 21/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6723 - accuracy: 0.5860 - val_loss: 0.6763 - val_accuracy: 0.5757
# Epoch 22/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6719 - accuracy: 0.5864 - val_loss: 0.6753 - val_accuracy: 0.5882
# Epoch 23/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6705 - accuracy: 0.5892 - val_loss: 0.6746 - val_accuracy: 0.5804
# Epoch 24/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.
100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6701 - accuracy: 0.5894 - val_loss: 0.6752 - val_accuracy: 0.5772
# Epoch 60/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6708 - accuracy: 0.5895 - val_loss: 0.6752 - val_accuracy: 0.5799
# Epoch 61/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6697 - accuracy: 0.5910 - val_loss: 0.6759 - val_accuracy: 0.5856
# Epoch 62/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6697 - accuracy: 0.5924 - val_loss: 0.6764 - val_accuracy: 0.5793
# Epoch 63/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6701 - accuracy: 0.5893 - val_loss: 0.6758 - val_accuracy: 0.5825
# Epoch 64/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6697 - accuracy: 0.5927 - val_loss: 0.6752 - val_accuracy: 0.5825
# Epoch 65/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6694 - accuracy: 0.5920 - val_loss: 0.6765 - val_accuracy: 0.5705
# Epoch 66/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6694 - accuracy: 0.5906 - val_loss: 0.6748 - val_accuracy: 0.5835
# Epoch 67/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6699 - accuracy: 0.5905 - val_loss: 0.6768 - val_accuracy: 0.5799
# Epoch 68/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6699 - accuracy: 0.5876 - val_loss: 0.6744 - val_accuracy: 0.5856
# Epoch 69/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6701 - accuracy: 0.5923 - val_loss: 0.6747 - val_accuracy: 0.5856

# %%
y_pred = model1.predict(X1_test)
y_pred_binary = (y_pred > 0.5).astype(int)
print(accuracy_score(y1_test, y_pred_binary))
# Out:
# 60/60 [==============================] - 1s 1ms/step
# 0.5793319415448852

# %%
#Now adding 3 point percentages
dfLim2 = df[[
    "date",
    "homeTeam",
    "homeTeamSubject_id", 
    "homeTeam_points_total", 
    #added homeTeam3P
    "homeTeam_3P",
    "awayTeam",
    "awayTeamSubject_id", 
    "awayTeam_points_total",
    #added awayTeam3P
    "awayTeam_3P",
    "winner"
]]
dfLim2
# Out:
#                  date               homeTeam  homeTeamSubject_id  \
# 0       June 17, 2024         Boston Celtics                   2
# 1       June 14, 2024       Dallas Mavericks                   7
# 2       June 12, 2024       Dallas Mavericks                   7
# 3       June 09, 2024         Boston Celtics                   2
# 4       June 06, 2024         Boston Celtics                   2
# ...               ...                    ...                 ...
# 12879  April 30, 2014        Houston Rockets                  11
# 12880  April 30, 2014      San Antonio Spurs                  27
# 12881  April 29, 2014          Chicago Bulls                   5
# 12882  April 29, 2014  Oklahoma City Thunder                  21
# 12883  April 29, 2014   Los Angeles Clippers                  13
#
#        homeTeam_points_total homeTeam_3P                awayTeam  \
# 0                        106       13-39        Dallas Mavericks
# 1                        122       15-37          Boston Celtics
# 2                         99        9-25          Boston Celtics
# 3                        105       10-39        Dallas Mavericks
# 4                        107       16-42        Dallas Mavericks
# ...                      ...         ...                     ...
# 12879                    108        8-25  Portland Trail Blazers
# 12880                    109        8-16        Dallas Mavericks
# 12881                     69        6-16      Washington Wizards
# 12882                     99       12-31       Memphis Grizzlies
# 12883                    113        8-20   Golden State Warriors
#
#        awayTeamSubject_id  awayTeam_points_total awayTeam_3P  \
# 0                       7                     88       11-37
# 1                       2                     84       14-41
# 2                       2                    106       17-46
# 3                       7                     98        6-26
# 4                       7                     89        7-27
# ...                   ...                    ...         ...
# 12879                  25                     98        9-25
# 12880                   7                    103       12-28
# 12881                  30                     75         2-9
# 12882                  15                    100        7-19
# 12883                  10                    103       10-26
#
#                      winner
# 0            Boston Celtics
# 1          Dallas Mavericks
# 2            Boston Celtics
# 3            Boston Celtics
# 4            Boston Celtics
# ...                     ...
# 12879       Houston Rockets
# 12880     San Antonio Spurs
# 12881    Washington Wizards
# 12882     Memphis Grizzlies
# 12883  Los Angeles Clippers
#
# [12884 rows x 10 columns]

# %%
#reformat the dates so they can be compared
dfLim2['date'] = dfLim2['date'].apply(lambda x: datetime.strptime(x, "%B %d, %Y"))
dfLim2
# Out:
# C:\Users\Max Braithwaite\AppData\Local\Temp\ipykernel_25820\2484283733.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfLim2['date'] = dfLim2['date'].apply(lambda x: datetime.strptime(x, "%B %d, %Y"))
#             date               homeTeam  homeTeamSubject_id  \
# 0     2024-06-17         Boston Celtics                   2
# 1     2024-06-14       Dallas Mavericks                   7
# 2     2024-06-12       Dallas Mavericks                   7
# 3     2024-06-09         Boston Celtics                   2
# 4     2024-06-06         Boston Celtics                   2
# ...          ...                    ...                 ...
# 12879 2014-04-30        Houston Rockets                  11
# 12880 2014-04-30      San Antonio Spurs                  27
# 12881 2014-04-29          Chicago Bulls                   5
# 12882 2014-04-29  Oklahoma City Thunder                  21
# 12883 2014-04-29   Los Angeles Clippers                  13
#
#        homeTeam_points_total homeTeam_3P                awayTeam  \
# 0                        106       13-39        Dallas Mavericks
# 1                        122       15-37          Boston Celtics
# 2                         99        9-25          Boston Celtics
# 3                        105       10-39        Dallas Mavericks
# 4                        107       16-42        Dallas Mavericks
# ...                      ...         ...                     ...
# 12879                    108        8-25  Portland Trail Blazers
# 12880                    109        8-16        Dallas Mavericks
# 12881                     69        6-16      Washington Wizards
# 12882                     99       12-31       Memphis Grizzlies
# 12883                    113        8-20   Golden State Warriors
#
#        awayTeamSubject_id  awayTeam_points_total awayTeam_3P  \
# 0                       7                     88       11-37
# 1                       2                     84       14-41
# 2                       2                    106       17-46
# 3                       7                     98        6-26
# 4                       7                     89        7-27
# ...                   ...                    ...         ...
# 12879                  25                     98        9-25
# 12880                   7                    103       12-28
# 12881                  30                     75         2-9
# 12882                  15                    100        7-19
# 12883                  10                    103       10-26
#
#                      winner
# 0            Boston Celtics
# 1          Dallas Mavericks
# 2            Boston Celtics
# 3            Boston Celtics
# 4            Boston Celtics
# ...                     ...
# 12879       Houston Rockets
# 12880     San Antonio Spurs
# 12881    Washington Wizards
# 12882     Memphis Grizzlies
# 12883  Los Angeles Clippers
#
# [12884 rows x 10 columns]

# %%
dfLim2['winner_binary'] = (dfLim2['winner'] == df['awayTeam']).astype(int)
dfLim2
# Out:
# C:\Users\Max Braithwaite\AppData\Local\Temp\ipykernel_25820\3063500590.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfLim2['winner_binary'] = (dfLim2['winner'] == df['awayTeam']).astype(int)
#             date               homeTeam  homeTeamSubject_id  \
# 0     2024-06-17         Boston Celtics                   2
# 1     2024-06-14       Dallas Mavericks                   7
# 2     2024-06-12       Dallas Mavericks                   7
# 3     2024-06-09         Boston Celtics                   2
# 4     2024-06-06         Boston Celtics                   2
# ...          ...                    ...                 ...
# 12879 2014-04-30        Houston Rockets                  11
# 12880 2014-04-30      San Antonio Spurs                  27
# 12881 2014-04-29          Chicago Bulls                   5
# 12882 2014-04-29  Oklahoma City Thunder                  21
# 12883 2014-04-29   Los Angeles Clippers                  13
#
#        homeTeam_points_total homeTeam_3P                awayTeam  \
# 0                        106       13-39        Dallas Mavericks
# 1                        122       15-37          Boston Celtics
# 2                         99        9-25          Boston Celtics
# 3                        105       10-39        Dallas Mavericks
# 4                        107       16-42        Dallas Mavericks
# ...                      ...         ...                     ...
# 12879                    108        8-25  Portland Trail Blazers
# 12880                    109        8-16        Dallas Mavericks
# 12881                     69        6-16      Washington Wizards
# 12882                     99       12-31       Memphis Grizzlies
# 12883                    113        8-20   Golden State Warriors
#
#        awayTeamSubject_id  awayTeam_points_total awayTeam_3P  \
# 0                       7                     88       11-37
# 1                       2                     84       14-41
# 2                       2                    106       17-46
# 3                       7                     98        6-26
# 4                       7                     89        7-27
# ...                   ...                    ...         ...
# 12879                  25                     98        9-25
# 12880                   7                    103       12-28
# 12881                  30                     75         2-9
# 12882                  15                    100        7-19
# 12883                  10                    103       10-26
#
#                      winner  winner_binary
# 0            Boston Celtics              0
# 1          Dallas Mavericks              0
# 2            Boston Celtics              1
# 3            Boston Celtics              0
# 4            Boston Celtics              0
# ...                     ...            ...
# 12879       Houston Rockets              0
# 12880     San Antonio Spurs              0
# 12881    Washington Wizards              1
# 12882     Memphis Grizzlies              1
# 12883  Los Angeles Clippers              0
#
# [12884 rows x 11 columns]

# %%
#Format as percentage
dfLim2['homeTeam_3P'] = dfLim2['homeTeam_3P'].str.split('-').apply(lambda x: int(x[0]) / int(x[1]) if isinstance(x, list) and len(x) == 2 else np.nan)
dfLim2['awayTeam_3P'] = dfLim2['awayTeam_3P'].str.split('-').apply(lambda x: int(x[0]) / int(x[1]) if isinstance(x, list) and len(x) == 2 else np.nan)
dfLim2
# Out:
# C:\Users\Max Braithwaite\AppData\Local\Temp\ipykernel_25820\2275991191.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfLim2['homeTeam_3P'] = dfLim2['homeTeam_3P'].str.split('-').apply(lambda x: int(x[0]) / int(x[1]) if isinstance(x, list) and len(x) == 2 else np.nan)
# C:\Users\Max Braithwaite\AppData\Local\Temp\ipykernel_25820\2275991191.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfLim2['awayTeam_3P'] = dfLim2['awayTeam_3P'].str.split('-').apply(lambda x: int(x[0]) / int(x[1]) if isinstance(x, list) and len(x) == 2 else np.nan)
#             date               homeTeam  homeTeamSubject_id  \
# 0     2024-06-17         Boston Celtics                   2
# 1     2024-06-14       Dallas Mavericks                   7
# 2     2024-06-12       Dallas Mavericks                   7
# 3     2024-06-09         Boston Celtics                   2
# 4     2024-06-06         Boston Celtics                   2
# ...          ...                    ...                 ...
# 12879 2014-04-30        Houston Rockets                  11
# 12880 2014-04-30      San Antonio Spurs                  27
# 12881 2014-04-29          Chicago Bulls                   5
# 12882 2014-04-29  Oklahoma City Thunder                  21
# 12883 2014-04-29   Los Angeles Clippers                  13
#
#        homeTeam_points_total  homeTeam_3P                awayTeam  \
# 0                        106     0.333333        Dallas Mavericks
# 1                        122     0.405405          Boston Celtics
# 2                         99     0.360000          Boston Celtics
# 3                        105     0.256410        Dallas Mavericks
# 4                        107     0.380952        Dallas Mavericks
# ...                      ...          ...                     ...
# 12879                    108     0.320000  Portland Trail Blazers
# 12880                    109     0.500000        Dallas Mavericks
# 12881                     69     0.375000      Washington Wizards
# 12882                     99     0.387097       Memphis Grizzlies
# 12883                    113     0.400000   Golden State Warriors
#
#        awayTeamSubject_id  awayTeam_points_total  awayTeam_3P  \
# 0                       7                     88     0.297297
# 1                       2                     84     0.341463
# 2                       2                    106     0.369565
# 3                       7                     98     0.230769
# 4                       7                     89     0.259259
# ...                   ...                    ...          ...
# 12879                  25                     98     0.360000
# 12880                   7                    103     0.428571
# 12881                  30                     75     0.222222
# 12882                  15                    100     0.368421
# 12883                  10                    103     0.384615
#
#                      winner  winner_binary
# 0            Boston Celtics              0
# 1          Dallas Mavericks              0
# 2            Boston Celtics              1
# 3            Boston Celtics              0
# 4            Boston Celtics              0
# ...                     ...            ...
# 12879       Houston Rockets              0
# 12880     San Antonio Spurs              0
# 12881    Washington Wizards              1
# 12882     Memphis Grizzlies              1
# 12883  Los Angeles Clippers              0
#
# [12884 rows x 11 columns]

# %%
dfIDtoStat2 = pd.DataFrame(columns=['date', 'team_id', 'team_points_total', '3P%'])
dfIDtoStat2
# Out:
# Empty DataFrame
# Columns: [date, team_id, team_points_total, 3P%]
# Index: []

# %%
#populate dfIDtoStat2
for index, row in dfLim2.iterrows():
    date = row['date']
    homeTeam_id = row['homeTeamSubject_id']
    homeTeam_points_total = row['homeTeam_points_total']
    #added homeTeam3P
    homeTeam_3P = row['homeTeam_3P']
    awayTeam_id = row['awayTeamSubject_id']
    awayTeam_points_total = row['awayTeam_points_total']
    #added awayTeam3P
    awayTeam_3P = row['homeTeam_3P']
    dfIDtoStat2.loc[len(dfIDtoStat2)] = {"date": date, 'team_id': homeTeam_id, 'team_points_total':homeTeam_points_total, '3P%':homeTeam_3P}
    dfIDtoStat2.loc[len(dfIDtoStat2)] = {"date": date, 'team_id': awayTeam_id, 'team_points_total':awayTeam_points_total, '3P%':awayTeam_3P}
dfIDtoStat2
# Out:
#             date  team_id  team_points_total       3P%
# 0     2024-06-17        2                106  0.333333
# 1     2024-06-17        7                 88  0.333333
# 2     2024-06-14        7                122  0.405405
# 3     2024-06-14        2                 84  0.405405
# 4     2024-06-12        7                 99  0.360000
# ...          ...      ...                ...       ...
# 25763 2014-04-29       30                 75  0.375000
# 25764 2014-04-29       21                 99  0.387097
# 25765 2014-04-29       15                100  0.387097
# 25766 2014-04-29       13                113  0.400000
# 25767 2014-04-29       10                103  0.400000
#
# [25768 rows x 4 columns]

# %%
#reverse df order - should now start with 2014
dfLim2 = dfLim2.iloc[::-1].reset_index(drop=True)
dfLim2
# Out:
#             date               homeTeam  homeTeamSubject_id  \
# 0     2014-04-29   Los Angeles Clippers                  13
# 1     2014-04-29  Oklahoma City Thunder                  21
# 2     2014-04-29          Chicago Bulls                   5
# 3     2014-04-30      San Antonio Spurs                  27
# 4     2014-04-30        Houston Rockets                  11
# ...          ...                    ...                 ...
# 12879 2024-06-06         Boston Celtics                   2
# 12880 2024-06-09         Boston Celtics                   2
# 12881 2024-06-12       Dallas Mavericks                   7
# 12882 2024-06-14       Dallas Mavericks                   7
# 12883 2024-06-17         Boston Celtics                   2
#
#        homeTeam_points_total  homeTeam_3P                awayTeam  \
# 0                        113     0.400000   Golden State Warriors
# 1                         99     0.387097       Memphis Grizzlies
# 2                         69     0.375000      Washington Wizards
# 3                        109     0.500000        Dallas Mavericks
# 4                        108     0.320000  Portland Trail Blazers
# ...                      ...          ...                     ...
# 12879                    107     0.380952        Dallas Mavericks
# 12880                    105     0.256410        Dallas Mavericks
# 12881                     99     0.360000          Boston Celtics
# 12882                    122     0.405405          Boston Celtics
# 12883                    106     0.333333        Dallas Mavericks
#
#        awayTeamSubject_id  awayTeam_points_total  awayTeam_3P  \
# 0                      10                    103     0.384615
# 1                      15                    100     0.368421
# 2                      30                     75     0.222222
# 3                       7                    103     0.428571
# 4                      25                     98     0.360000
# ...                   ...                    ...          ...
# 12879                   7                     89     0.259259
# 12880                   7                     98     0.230769
# 12881                   2                    106     0.369565
# 12882                   2                     84     0.341463
# 12883                   7                     88     0.297297
#
#                      winner  winner_binary
# 0      Los Angeles Clippers              0
# 1         Memphis Grizzlies              1
# 2        Washington Wizards              1
# 3         San Antonio Spurs              0
# 4           Houston Rockets              0
# ...                     ...            ...
# 12879        Boston Celtics              0
# 12880        Boston Celtics              0
# 12881        Boston Celtics              1
# 12882      Dallas Mavericks              0
# 12883        Boston Celtics              0
#
# [12884 rows x 11 columns]

# %%
#reverse order - should now start with 2014
dfIDtoStat2 = dfIDtoStat2.iloc[::-1].reset_index(drop=True)
dfIDtoStat2
# Out:
#             date  team_id  team_points_total       3P%
# 0     2014-04-29       10                103  0.400000
# 1     2014-04-29       13                113  0.400000
# 2     2014-04-29       15                100  0.387097
# 3     2014-04-29       21                 99  0.387097
# 4     2014-04-29       30                 75  0.375000
# ...          ...      ...                ...       ...
# 25763 2024-06-12        7                 99  0.360000
# 25764 2024-06-14        2                 84  0.405405
# 25765 2024-06-14        7                122  0.405405
# 25766 2024-06-17        7                 88  0.333333
# 25767 2024-06-17        2                106  0.333333
#
# [25768 rows x 4 columns]

# %%
#X1.Shape is num data, window size, variables
X2, y2 = df_to_X_y(dfLim2, dfIDtoStat2, 5)
X2.shape, y2.shape
# Out:
# ((12773, 5, 4), (12773,))

# %%
#70-15-15 split
X2_train, X2_temp, y2_train, y2_temp = train_test_split(X2, y2, test_size=0.3, random_state=42)
X2_val, X2_test, y2_val, y2_test = train_test_split(X2_temp, y2_temp, test_size=0.5, random_state=42)
X2_train.shape, y2_train.shape, X2_val.shape, y2_val.shape, X2_test.shape, y2_test.shape
# Out:
# ((8941, 5, 4), (8941,), (1916, 5, 4), (1916,), (1916, 5, 4), (1916,))

# %%
model2 = Sequential()
#You need to change the input layer to reflect the amount of variables. first number is window size, second is variables
model2.add(InputLayer((5, 4)))
model2.add(LSTM(64, activation='tanh', return_sequences=True))
model2.add(LSTM(32, activation='tanh'))
model2.add(Dense(16, activation='relu'))
model2.add(Dense(8, activation='relu'))
model2.add(Dense(1, activation='sigmoid'))

model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 5, 64)             17664
#
#  lstm_5 (LSTM)               (None, 32)                12416
#
#  dense_3 (Dense)             (None, 16)                528
#
#  dense_4 (Dense)             (None, 8)                 136
#
#  dense_5 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 30753 (120.13 KB)
# Trainable params: 30753 (120.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
earlystopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
model2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model2.fit(X2_train, y2_train, validation_data=(X2_val, y2_val), epochs=100, callbacks=[earlystopping])
# Out:
# Epoch 1/100
# 280/280 [==============================] - 4s 6ms/step - loss: 0.6766 - accuracy: 0.5799 - val_loss: 0.6756 - val_accuracy: 0.5804
# Epoch 2/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.
100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6700 - accuracy: 0.5914 - val_loss: 0.6765 - val_accuracy: 0.5783
# Epoch 36/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6704 - accuracy: 0.5887 - val_loss: 0.6741 - val_accuracy: 0.5835
# Epoch 37/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6713 - accuracy: 0.5873 - val_loss: 0.6763 - val_accuracy: 0.5887
# Epoch 38/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6704 - accuracy: 0.5866 - val_loss: 0.6759 - val_accuracy: 0.5825
# Epoch 39/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6701 - accuracy: 0.5913 - val_loss: 0.6787 - val_accuracy: 0.5856
# Epoch 40/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6707 - accuracy: 0.5898 - val_loss: 0.6747 - val_accuracy: 0.5882
# Epoch 41/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6706 - accuracy: 0.5908 - val_loss: 0.6748 - val_accuracy: 0.5804
# Epoch 42/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6697 - accuracy: 0.5946 - val_loss: 0.6761 - val_accuracy: 0.5689
# Epoch 43/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6702 - accuracy: 0.5921 - val_loss: 0.6767 - val_accuracy: 0.5788
# Epoch 44/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6697 - accuracy: 0.5895 - val_loss: 0.6762 - val_accuracy: 0.5830
# Epoch 45/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6706 - accuracy: 0.5862 - val_loss: 0.6764 - val_accuracy: 0.5825
# Epoch 46/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6703 - accuracy: 0.5884 - val_loss: 0.6759 - val_accuracy: 0.5778
# Epoch 47/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6699 - accuracy: 0.5903 - val_loss: 0.6757 - val_accuracy: 0.5846
# Epoch 48/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6697 - accuracy: 0.5933 - val_loss: 0.6751 - val_accuracy: 0.5830
# Epoch 49/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6697 - accuracy: 0.5885 - val_loss: 0.6760 - val_accuracy: 0.5846
# Epoch 50/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6693 - accuracy: 0.5911 - val_loss: 0.6772 - val_accuracy: 0.5710
# Epoch 51/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6698 - accuracy: 0.5934 - val_loss: 0.6747 - val_accuracy: 0.5830
# Epoch 52/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6706 - accuracy: 0.5893 - val_loss: 0.6798 - val_accuracy: 0.5819
# Epoch 53/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6702 - accuracy: 0.5872 - val_loss: 0.6744 - val_accuracy: 0.5866
# Epoch 54/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6688 - accuracy: 0.5899 - val_loss: 0.6783 - val_accuracy: 0.5793
# Epoch 55/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6700 - accuracy: 0.5893 - val_loss: 0.6758 - val_accuracy: 0.5861
# Epoch 56/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6702 - accuracy: 0.5894 - val_loss: 0.6750 - val_accuracy: 0.5825
# Epoch 57/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6689 - accuracy: 0.5929 - val_loss: 0.6771 - val_accuracy: 0.5819
# Epoch 58/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6694 - accuracy: 0.5905 - val_loss: 0.6762 - val_accuracy: 0.5793
# Epoch 59/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6692 - accuracy: 0.5908 - val_loss: 0.6750 - val_accuracy: 0.5861
# Epoch 60/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6682 - accuracy: 0.5981 - val_loss: 0.6784 - val_accuracy: 0.5840
# Epoch 61/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6691 - accuracy: 0.5924 - val_loss: 0.6758 - val_accuracy: 0.5872

# %%
y_pred = model2.predict(X2_test)
y_pred_binary = (y_pred > 0.5).astype(int)
print(accuracy_score(y2_test, y_pred_binary))
# Out:
# 60/60 [==============================] - 1s 2ms/step
# 0.587160751565762

# %%
#Not adding anything new because I am gonna pull out 3 pointers made
dfLim3 = df[[
    "date",
    "homeTeam",
    "homeTeamSubject_id", 
    "homeTeam_points_total", 
    #added homeTeam3P
    "homeTeam_3P",
    "awayTeam",
    "awayTeamSubject_id", 
    "awayTeam_points_total",
    #added awayTeam3P
    "awayTeam_3P",
    "winner"
]]
dfLim3
# Out:
#                  date               homeTeam  homeTeamSubject_id  \
# 0       June 17, 2024         Boston Celtics                   2
# 1       June 14, 2024       Dallas Mavericks                   7
# 2       June 12, 2024       Dallas Mavericks                   7
# 3       June 09, 2024         Boston Celtics                   2
# 4       June 06, 2024         Boston Celtics                   2
# ...               ...                    ...                 ...
# 12879  April 30, 2014        Houston Rockets                  11
# 12880  April 30, 2014      San Antonio Spurs                  27
# 12881  April 29, 2014          Chicago Bulls                   5
# 12882  April 29, 2014  Oklahoma City Thunder                  21
# 12883  April 29, 2014   Los Angeles Clippers                  13
#
#        homeTeam_points_total homeTeam_3P                awayTeam  \
# 0                        106       13-39        Dallas Mavericks
# 1                        122       15-37          Boston Celtics
# 2                         99        9-25          Boston Celtics
# 3                        105       10-39        Dallas Mavericks
# 4                        107       16-42        Dallas Mavericks
# ...                      ...         ...                     ...
# 12879                    108        8-25  Portland Trail Blazers
# 12880                    109        8-16        Dallas Mavericks
# 12881                     69        6-16      Washington Wizards
# 12882                     99       12-31       Memphis Grizzlies
# 12883                    113        8-20   Golden State Warriors
#
#        awayTeamSubject_id  awayTeam_points_total awayTeam_3P  \
# 0                       7                     88       11-37
# 1                       2                     84       14-41
# 2                       2                    106       17-46
# 3                       7                     98        6-26
# 4                       7                     89        7-27
# ...                   ...                    ...         ...
# 12879                  25                     98        9-25
# 12880                   7                    103       12-28
# 12881                  30                     75         2-9
# 12882                  15                    100        7-19
# 12883                  10                    103       10-26
#
#                      winner
# 0            Boston Celtics
# 1          Dallas Mavericks
# 2            Boston Celtics
# 3            Boston Celtics
# 4            Boston Celtics
# ...                     ...
# 12879       Houston Rockets
# 12880     San Antonio Spurs
# 12881    Washington Wizards
# 12882     Memphis Grizzlies
# 12883  Los Angeles Clippers
#
# [12884 rows x 10 columns]

# %%
#reformat the dates so they can be compared
dfLim3['date'] = dfLim3['date'].apply(lambda x: datetime.strptime(x, "%B %d, %Y"))
dfLim3
# Out:
# C:\Users\Max Braithwaite\AppData\Local\Temp\ipykernel_25820\3422671400.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfLim3['date'] = dfLim3['date'].apply(lambda x: datetime.strptime(x, "%B %d, %Y"))
#             date               homeTeam  homeTeamSubject_id  \
# 0     2024-06-17         Boston Celtics                   2
# 1     2024-06-14       Dallas Mavericks                   7
# 2     2024-06-12       Dallas Mavericks                   7
# 3     2024-06-09         Boston Celtics                   2
# 4     2024-06-06         Boston Celtics                   2
# ...          ...                    ...                 ...
# 12879 2014-04-30        Houston Rockets                  11
# 12880 2014-04-30      San Antonio Spurs                  27
# 12881 2014-04-29          Chicago Bulls                   5
# 12882 2014-04-29  Oklahoma City Thunder                  21
# 12883 2014-04-29   Los Angeles Clippers                  13
#
#        homeTeam_points_total homeTeam_3P                awayTeam  \
# 0                        106       13-39        Dallas Mavericks
# 1                        122       15-37          Boston Celtics
# 2                         99        9-25          Boston Celtics
# 3                        105       10-39        Dallas Mavericks
# 4                        107       16-42        Dallas Mavericks
# ...                      ...         ...                     ...
# 12879                    108        8-25  Portland Trail Blazers
# 12880                    109        8-16        Dallas Mavericks
# 12881                     69        6-16      Washington Wizards
# 12882                     99       12-31       Memphis Grizzlies
# 12883                    113        8-20   Golden State Warriors
#
#        awayTeamSubject_id  awayTeam_points_total awayTeam_3P  \
# 0                       7                     88       11-37
# 1                       2                     84       14-41
# 2                       2                    106       17-46
# 3                       7                     98        6-26
# 4                       7                     89        7-27
# ...                   ...                    ...         ...
# 12879                  25                     98        9-25
# 12880                   7                    103       12-28
# 12881                  30                     75         2-9
# 12882                  15                    100        7-19
# 12883                  10                    103       10-26
#
#                      winner
# 0            Boston Celtics
# 1          Dallas Mavericks
# 2            Boston Celtics
# 3            Boston Celtics
# 4            Boston Celtics
# ...                     ...
# 12879       Houston Rockets
# 12880     San Antonio Spurs
# 12881    Washington Wizards
# 12882     Memphis Grizzlies
# 12883  Los Angeles Clippers
#
# [12884 rows x 10 columns]

# %%
dfLim3['winner_binary'] = (dfLim3['winner'] == df['awayTeam']).astype(int)
dfLim3
# Out:
# C:\Users\Max Braithwaite\AppData\Local\Temp\ipykernel_25820\309887304.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfLim3['winner_binary'] = (dfLim3['winner'] == df['awayTeam']).astype(int)
#             date               homeTeam  homeTeamSubject_id  \
# 0     2024-06-17         Boston Celtics                   2
# 1     2024-06-14       Dallas Mavericks                   7
# 2     2024-06-12       Dallas Mavericks                   7
# 3     2024-06-09         Boston Celtics                   2
# 4     2024-06-06         Boston Celtics                   2
# ...          ...                    ...                 ...
# 12879 2014-04-30        Houston Rockets                  11
# 12880 2014-04-30      San Antonio Spurs                  27
# 12881 2014-04-29          Chicago Bulls                   5
# 12882 2014-04-29  Oklahoma City Thunder                  21
# 12883 2014-04-29   Los Angeles Clippers                  13
#
#        homeTeam_points_total homeTeam_3P                awayTeam  \
# 0                        106       13-39        Dallas Mavericks
# 1                        122       15-37          Boston Celtics
# 2                         99        9-25          Boston Celtics
# 3                        105       10-39        Dallas Mavericks
# 4                        107       16-42        Dallas Mavericks
# ...                      ...         ...                     ...
# 12879                    108        8-25  Portland Trail Blazers
# 12880                    109        8-16        Dallas Mavericks
# 12881                     69        6-16      Washington Wizards
# 12882                     99       12-31       Memphis Grizzlies
# 12883                    113        8-20   Golden State Warriors
#
#        awayTeamSubject_id  awayTeam_points_total awayTeam_3P  \
# 0                       7                     88       11-37
# 1                       2                     84       14-41
# 2                       2                    106       17-46
# 3                       7                     98        6-26
# 4                       7                     89        7-27
# ...                   ...                    ...         ...
# 12879                  25                     98        9-25
# 12880                   7                    103       12-28
# 12881                  30                     75         2-9
# 12882                  15                    100        7-19
# 12883                  10                    103       10-26
#
#                      winner  winner_binary
# 0            Boston Celtics              0
# 1          Dallas Mavericks              0
# 2            Boston Celtics              1
# 3            Boston Celtics              0
# 4            Boston Celtics              0
# ...                     ...            ...
# 12879       Houston Rockets              0
# 12880     San Antonio Spurs              0
# 12881    Washington Wizards              1
# 12882     Memphis Grizzlies              1
# 12883  Los Angeles Clippers              0
#
# [12884 rows x 11 columns]

# %%
dfLim3.insert(dfLim3.columns.get_loc('homeTeam_3P') + 1, 'homeTeam_3P_made', dfLim3['homeTeam_3P'].str.split('-').apply(lambda x: int(x[0]) if isinstance(x, list) and len(x) == 2 else np.nan))
dfLim3.insert(dfLim3.columns.get_loc('awayTeam_3P') + 1, 'awayTeam_3P_made', dfLim3['awayTeam_3P'].str.split('-').apply(lambda x: int(x[0]) if isinstance(x, list) and len(x) == 2 else np.nan))
dfLim3
# Out:
#             date               homeTeam  homeTeamSubject_id  \
# 0     2024-06-17         Boston Celtics                   2
# 1     2024-06-14       Dallas Mavericks                   7
# 2     2024-06-12       Dallas Mavericks                   7
# 3     2024-06-09         Boston Celtics                   2
# 4     2024-06-06         Boston Celtics                   2
# ...          ...                    ...                 ...
# 12879 2014-04-30        Houston Rockets                  11
# 12880 2014-04-30      San Antonio Spurs                  27
# 12881 2014-04-29          Chicago Bulls                   5
# 12882 2014-04-29  Oklahoma City Thunder                  21
# 12883 2014-04-29   Los Angeles Clippers                  13
#
#        homeTeam_points_total homeTeam_3P  homeTeam_3P_made  \
# 0                        106       13-39                13
# 1                        122       15-37                15
# 2                         99        9-25                 9
# 3                        105       10-39                10
# 4                        107       16-42                16
# ...                      ...         ...               ...
# 12879                    108        8-25                 8
# 12880                    109        8-16                 8
# 12881                     69        6-16                 6
# 12882                     99       12-31                12
# 12883                    113        8-20                 8
#
#                      awayTeam  awayTeamSubject_id  awayTeam_points_total  \
# 0            Dallas Mavericks                   7                     88
# 1              Boston Celtics                   2                     84
# 2              Boston Celtics                   2                    106
# 3            Dallas Mavericks                   7                     98
# 4            Dallas Mavericks                   7                     89
# ...                       ...                 ...                    ...
# 12879  Portland Trail Blazers                  25                     98
# 12880        Dallas Mavericks                   7                    103
# 12881      Washington Wizards                  30                     75
# 12882       Memphis Grizzlies                  15                    100
# 12883   Golden State Warriors                  10                    103
#
#       awayTeam_3P  awayTeam_3P_made                winner  winner_binary
# 0           11-37                11        Boston Celtics              0
# 1           14-41                14      Dallas Mavericks              0
# 2           17-46                17        Boston Celtics              1
# 3            6-26                 6        Boston Celtics              0
# 4            7-27                 7        Boston Celtics              0
# ...           ...               ...                   ...            ...
# 12879        9-25                 9       Houston Rockets              0
# 12880       12-28                12     San Antonio Spurs              0
# 12881         2-9                 2    Washington Wizards              1
# 12882        7-19                 7     Memphis Grizzlies              1
# 12883       10-26                10  Los Angeles Clippers              0
#
# [12884 rows x 13 columns]

# %%
#Format as percentage
dfLim3['homeTeam_3P'] = dfLim3['homeTeam_3P'].str.split('-').apply(lambda x: int(x[0]) / int(x[1]) if isinstance(x, list) and len(x) == 2 else np.nan)
dfLim3['awayTeam_3P'] = dfLim3['awayTeam_3P'].str.split('-').apply(lambda x: int(x[0]) / int(x[1]) if isinstance(x, list) and len(x) == 2 else np.nan)
dfLim3
# Out:
# C:\Users\Max Braithwaite\AppData\Local\Temp\ipykernel_25820\574364315.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfLim3['homeTeam_3P'] = dfLim3['homeTeam_3P'].str.split('-').apply(lambda x: int(x[0]) / int(x[1]) if isinstance(x, list) and len(x) == 2 else np.nan)
# C:\Users\Max Braithwaite\AppData\Local\Temp\ipykernel_25820\574364315.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfLim3['awayTeam_3P'] = dfLim3['awayTeam_3P'].str.split('-').apply(lambda x: int(x[0]) / int(x[1]) if isinstance(x, list) and len(x) == 2 else np.nan)
#             date               homeTeam  homeTeamSubject_id  \
# 0     2024-06-17         Boston Celtics                   2
# 1     2024-06-14       Dallas Mavericks                   7
# 2     2024-06-12       Dallas Mavericks                   7
# 3     2024-06-09         Boston Celtics                   2
# 4     2024-06-06         Boston Celtics                   2
# ...          ...                    ...                 ...
# 12879 2014-04-30        Houston Rockets                  11
# 12880 2014-04-30      San Antonio Spurs                  27
# 12881 2014-04-29          Chicago Bulls                   5
# 12882 2014-04-29  Oklahoma City Thunder                  21
# 12883 2014-04-29   Los Angeles Clippers                  13
#
#        homeTeam_points_total  homeTeam_3P  homeTeam_3P_made  \
# 0                        106     0.333333                13
# 1                        122     0.405405                15
# 2                         99     0.360000                 9
# 3                        105     0.256410                10
# 4                        107     0.380952                16
# ...                      ...          ...               ...
# 12879                    108     0.320000                 8
# 12880                    109     0.500000                 8
# 12881                     69     0.375000                 6
# 12882                     99     0.387097                12
# 12883                    113     0.400000                 8
#
#                      awayTeam  awayTeamSubject_id  awayTeam_points_total  \
# 0            Dallas Mavericks                   7                     88
# 1              Boston Celtics                   2                     84
# 2              Boston Celtics                   2                    106
# 3            Dallas Mavericks                   7                     98
# 4            Dallas Mavericks                   7                     89
# ...                       ...                 ...                    ...
# 12879  Portland Trail Blazers                  25                     98
# 12880        Dallas Mavericks                   7                    103
# 12881      Washington Wizards                  30                     75
# 12882       Memphis Grizzlies                  15                    100
# 12883   Golden State Warriors                  10                    103
#
#        awayTeam_3P  awayTeam_3P_made                winner  winner_binary
# 0         0.297297                11        Boston Celtics              0
# 1         0.341463                14      Dallas Mavericks              0
# 2         0.369565                17        Boston Celtics              1
# 3         0.230769                 6        Boston Celtics              0
# 4         0.259259                 7        Boston Celtics              0
# ...            ...               ...                   ...            ...
# 12879     0.360000                 9       Houston Rockets              0
# 12880     0.428571                12     San Antonio Spurs              0
# 12881     0.222222                 2    Washington Wizards              1
# 12882     0.368421                 7     Memphis Grizzlies              1
# 12883     0.384615                10  Los Angeles Clippers              0
#
# [12884 rows x 13 columns]

# %%
dfIDtoStat3 = pd.DataFrame(columns=['date', 'team_id', 'team_points_total', '3P%', '3P_made'])
dfIDtoStat3
# Out:
# Empty DataFrame
# Columns: [date, team_id, team_points_total, 3P%, 3P_made]
# Index: []

# %%
#populate dfIDtoStat3
for index, row in dfLim3.iterrows():
    date = row['date']
    homeTeam_id = row['homeTeamSubject_id']
    homeTeam_points_total = row['homeTeam_points_total']
    homeTeam_3P = row['homeTeam_3P']
    #added homeTeam3P_made
    homeTeam_3P_made = row['homeTeam_3P_made']
    awayTeam_id = row['awayTeamSubject_id']
    awayTeam_points_total = row['awayTeam_points_total']
    awayTeam_3P = row['homeTeam_3P']
    #added awayTeam3P_made
    awayTeam_3P_made = row['awayTeam_3P_made']
    #added these new variables into this
    dfIDtoStat3.loc[len(dfIDtoStat3)] = {"date": date, 'team_id': homeTeam_id, 'team_points_total':homeTeam_points_total, '3P%':homeTeam_3P, '3P_made':homeTeam_3P_made}
    dfIDtoStat3.loc[len(dfIDtoStat3)] = {"date": date, 'team_id': awayTeam_id, 'team_points_total':awayTeam_points_total, '3P%':awayTeam_3P, '3P_made':awayTeam_3P_made}
dfIDtoStat3
# Out:
#             date  team_id  team_points_total       3P%  3P_made
# 0     2024-06-17        2                106  0.333333       13
# 1     2024-06-17        7                 88  0.333333       11
# 2     2024-06-14        7                122  0.405405       15
# 3     2024-06-14        2                 84  0.405405       14
# 4     2024-06-12        7                 99  0.360000        9
# ...          ...      ...                ...       ...      ...
# 25763 2014-04-29       30                 75  0.375000        2
# 25764 2014-04-29       21                 99  0.387097       12
# 25765 2014-04-29       15                100  0.387097        7
# 25766 2014-04-29       13                113  0.400000        8
# 25767 2014-04-29       10                103  0.400000       10
#
# [25768 rows x 5 columns]

# %%
#reverse df order - should now start with 2014
dfLim3 = dfLim3.iloc[::-1].reset_index(drop=True)
dfLim3
# Out:
#             date               homeTeam  homeTeamSubject_id  \
# 0     2014-04-29   Los Angeles Clippers                  13
# 1     2014-04-29  Oklahoma City Thunder                  21
# 2     2014-04-29          Chicago Bulls                   5
# 3     2014-04-30      San Antonio Spurs                  27
# 4     2014-04-30        Houston Rockets                  11
# ...          ...                    ...                 ...
# 12879 2024-06-06         Boston Celtics                   2
# 12880 2024-06-09         Boston Celtics                   2
# 12881 2024-06-12       Dallas Mavericks                   7
# 12882 2024-06-14       Dallas Mavericks                   7
# 12883 2024-06-17         Boston Celtics                   2
#
#        homeTeam_points_total  homeTeam_3P  homeTeam_3P_made  \
# 0                        113     0.400000                 8
# 1                         99     0.387097                12
# 2                         69     0.375000                 6
# 3                        109     0.500000                 8
# 4                        108     0.320000                 8
# ...                      ...          ...               ...
# 12879                    107     0.380952                16
# 12880                    105     0.256410                10
# 12881                     99     0.360000                 9
# 12882                    122     0.405405                15
# 12883                    106     0.333333                13
#
#                      awayTeam  awayTeamSubject_id  awayTeam_points_total  \
# 0       Golden State Warriors                  10                    103
# 1           Memphis Grizzlies                  15                    100
# 2          Washington Wizards                  30                     75
# 3            Dallas Mavericks                   7                    103
# 4      Portland Trail Blazers                  25                     98
# ...                       ...                 ...                    ...
# 12879        Dallas Mavericks                   7                     89
# 12880        Dallas Mavericks                   7                     98
# 12881          Boston Celtics                   2                    106
# 12882          Boston Celtics                   2                     84
# 12883        Dallas Mavericks                   7                     88
#
#        awayTeam_3P  awayTeam_3P_made                winner  winner_binary
# 0         0.384615                10  Los Angeles Clippers              0
# 1         0.368421                 7     Memphis Grizzlies              1
# 2         0.222222                 2    Washington Wizards              1
# 3         0.428571                12     San Antonio Spurs              0
# 4         0.360000                 9       Houston Rockets              0
# ...            ...               ...                   ...            ...
# 12879     0.259259                 7        Boston Celtics              0
# 12880     0.230769                 6        Boston Celtics              0
# 12881     0.369565                17        Boston Celtics              1
# 12882     0.341463                14      Dallas Mavericks              0
# 12883     0.297297                11        Boston Celtics              0
#
# [12884 rows x 13 columns]

# %%
#reverse order - should now start with 2014
dfIDtoStat3 = dfIDtoStat3.iloc[::-1].reset_index(drop=True)
dfIDtoStat3
# Out:
#             date  team_id  team_points_total       3P%  3P_made
# 0     2014-04-29       10                103  0.400000       10
# 1     2014-04-29       13                113  0.400000        8
# 2     2014-04-29       15                100  0.387097        7
# 3     2014-04-29       21                 99  0.387097       12
# 4     2014-04-29       30                 75  0.375000        2
# ...          ...      ...                ...       ...      ...
# 25763 2024-06-12        7                 99  0.360000        9
# 25764 2024-06-14        2                 84  0.405405       14
# 25765 2024-06-14        7                122  0.405405       15
# 25766 2024-06-17        7                 88  0.333333       11
# 25767 2024-06-17        2                106  0.333333       13
#
# [25768 rows x 5 columns]

# %%
#X1.Shape is num data, window size, variables
X3, y3 = df_to_X_y(dfLim3, dfIDtoStat3, 5)
X3.shape, y3.shape
# Out:
# ((12773, 5, 6), (12773,))

# %%
#70-15-15 split
X3_train, X3_temp, y3_train, y3_temp = train_test_split(X3, y3, test_size=0.3, random_state=42)
X3_val, X3_test, y3_val, y3_test = train_test_split(X3_temp, y3_temp, test_size=0.5, random_state=42)
X3_train.shape, y3_train.shape, X3_val.shape, y3_val.shape, X3_test.shape, y3_test.shape
# Out:
# ((8941, 5, 6), (8941,), (1916, 5, 6), (1916,), (1916, 5, 6), (1916,))

# %%
model3 = Sequential()
#You need to change the input layer to reflect the amount of variables. first number is window size, second is variables
model3.add(InputLayer((5, 6)))
model3.add(LSTM(64, activation='tanh', return_sequences=True))
model3.add(LSTM(32, activation='tanh'))
model3.add(Dense(16, activation='relu'))
model3.add(Dense(8, activation='relu'))
model3.add(Dense(1, activation='sigmoid'))

model3.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 5, 64)             18176
#
#  lstm_7 (LSTM)               (None, 32)                12416
#
#  dense_6 (Dense)             (None, 16)                528
#
#  dense_7 (Dense)             (None, 8)                 136
#
#  dense_8 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 31265 (122.13 KB)
# Trainable params: 31265 (122.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
earlystopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
model3.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model3.fit(X3_train, y3_train, validation_data=(X3_val, y3_val), epochs=100, callbacks=[earlystopping])
# Out:
# Epoch 1/100
# 280/280 [==============================] - 5s 6ms/step - loss: 0.6774 - accuracy: 0.5729 - val_loss: 0.6755 - val_accuracy: 0.5694
# Epoch 2/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6732 - accuracy: 0.5804 - val_loss: 0.6806 - val_accuracy: 0.5804
# Epoch 3/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6737 - accuracy: 0.5826 - val_loss: 0.6733 - val_accuracy: 0.5840
# Epoch 4/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6730 - accuracy: 0.5854 - val_loss: 0.6739 - val_accuracy: 0.5919
# Epoch 5/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6720 - accuracy: 0.5885 - val_loss: 0.6725 - val_accuracy: 0.5913
# Epoch 6/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6715 - accuracy: 0.5887 - val_loss: 0.6788 - val_accuracy: 0.5710
# Epoch 7/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.
100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6650 - accuracy: 0.5946 - val_loss: 0.6740 - val_accuracy: 0.5903
# Epoch 73/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6660 - accuracy: 0.5967 - val_loss: 0.6759 - val_accuracy: 0.5736
# Epoch 74/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6654 - accuracy: 0.5958 - val_loss: 0.6719 - val_accuracy: 0.5799
# Epoch 75/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6651 - accuracy: 0.5953 - val_loss: 0.6725 - val_accuracy: 0.5887
# Epoch 76/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6652 - accuracy: 0.5950 - val_loss: 0.6751 - val_accuracy: 0.5741
# Epoch 77/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6647 - accuracy: 0.5959 - val_loss: 0.6734 - val_accuracy: 0.5877
# Epoch 78/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6641 - accuracy: 0.5977 - val_loss: 0.6759 - val_accuracy: 0.5731
# Epoch 79/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6640 - accuracy: 0.5970 - val_loss: 0.6731 - val_accuracy: 0.5783
# Epoch 80/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6636 - accuracy: 0.5975 - val_loss: 0.6720 - val_accuracy: 0.5908
# Epoch 81/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6646 - accuracy: 0.5972 - val_loss: 0.6790 - val_accuracy: 0.5898
# Epoch 82/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6648 - accuracy: 0.5977 - val_loss: 0.6746 - val_accuracy: 0.5809
# Epoch 83/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6626 - accuracy: 0.5996 - val_loss: 0.6729 - val_accuracy: 0.5835
# Epoch 84/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6636 - accuracy: 0.5994 - val_loss: 0.6753 - val_accuracy: 0.5830
# Epoch 85/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6619 - accuracy: 0.6011 - val_loss: 0.6738 - val_accuracy: 0.5788
# Epoch 86/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6634 - accuracy: 0.5994 - val_loss: 0.6763 - val_accuracy: 0.5809
# Epoch 87/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6615 - accuracy: 0.6037 - val_loss: 0.6770 - val_accuracy: 0.5840
# Epoch 88/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6615 - accuracy: 0.6037 - val_loss: 0.6738 - val_accuracy: 0.5746
# Epoch 89/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6605 - accuracy: 0.6040 - val_loss: 0.6753 - val_accuracy: 0.5887
# Epoch 90/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6611 - accuracy: 0.5995 - val_loss: 0.6743 - val_accuracy: 0.5804
# Epoch 91/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6628 - accuracy: 0.6063 - val_loss: 0.6758 - val_accuracy: 0.5861
# Epoch 92/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6605 - accuracy: 0.6037 - val_loss: 0.6777 - val_accuracy: 0.5846
# Epoch 93/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6589 - accuracy: 0.6079 - val_loss: 0.6792 - val_accuracy: 0.5767
# Epoch 94/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6599 - accuracy: 0.6027 - val_loss: 0.6789 - val_accuracy: 0.5804
# Epoch 95/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6580 - accuracy: 0.6033 - val_loss: 0.6841 - val_accuracy: 0.5835
# Epoch 96/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6596 - accuracy: 0.6018 - val_loss: 0.6810 - val_accuracy: 0.5814
# Epoch 97/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6562 - accuracy: 0.6098 - val_loss: 0.6856 - val_accuracy: 0.5715
# Epoch 98/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6563 - accuracy: 0.6090 - val_loss: 0.6795 - val_accuracy: 0.5741
# Epoch 99/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6541 - accuracy: 0.6126 - val_loss: 0.6860 - val_accuracy: 0.5908
# Epoch 100/100
# 280/280 [==============================] - 1s 4ms/step - loss: 0.6572 - accuracy: 0.6060 - val_loss: 0.6782 - val_accuracy: 0.5752

# %%
y_pred = model3.predict(X3_test)
y_pred_binary = (y_pred > 0.5).astype(int)
print(accuracy_score(y3_test, y_pred_binary))
# Out:
# 60/60 [==============================] - 0s 1ms/step
# 0.5735908141962421
